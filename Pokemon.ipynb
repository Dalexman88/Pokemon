# %%
import requests

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
r = requests.get('https://pokeapi.co/api/v2/pokemon/haunter')

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'abilities': [{'ability': {'name': 'levitate',
#     'url': 'https://pokeapi.co/api/v2/ability/26/'},
#    'is_hidden': False,
#    'slot': 1}],
#  'base_experience': 142,
#  'forms': [{'name': 'haunter',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/93/'}],
#  'game_indices': [{'game_index': 147,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 147,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 147,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 93,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 93,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 93,
#    'version': {'name': 'crystal',
#     'url': 'https://pokeapi.co/api/v2/version/6/'}},
#   {'game_index': 93,
# ...

# %%
r.json()['abilities']
# Out:
# [{'ability': {'name': 'levitate',
#    'url': 'https://pokeapi.co/api/v2/ability/26/'},
#   'is_hidden': False,
#   'slot': 1}]

# %%
r.json()['name']
# Out:
# 'haunter'

# %%
r.json()['base_experience']
# Out:
# 142

# %%
r.json()['sprites']
# Out:
# {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/93.png',
#  'back_female': None,
#  'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/shiny/93.png',
#  'back_shiny_female': None,
#  'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/93.png',
#  'front_female': None,
#  'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/93.png',
#  'front_shiny_female': None,
#  'other': {'dream_world': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/dream-world/93.svg',
#    'front_female': None},
#   'home': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/93.png',
#    'front_female': None,
#    'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/shiny/93.png',
# ...

# %%
r = requests.get('https://pokeapi.co/api/v2/pokemon/blastoise')

# %%
r.status_code
# Out:
# 200

# %%
r.json()['name']
# Out:
# 'blastoise'

# %%
r.json()['abilities']
# Out:
# [{'ability': {'name': 'torrent',
#    'url': 'https://pokeapi.co/api/v2/ability/67/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'rain-dish',
#    'url': 'https://pokeapi.co/api/v2/ability/44/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
r.json()['base_experience']
# Out:
# 265

# %%
r.json()['sprites']
# Out:
# {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/9.png',
#  'back_female': None,
#  'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/shiny/9.png',
#  'back_shiny_female': None,
#  'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/9.png',
#  'front_female': None,
#  'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/9.png',
#  'front_shiny_female': None,
#  'other': {'dream_world': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/dream-world/9.svg',
#    'front_female': None},
#   'home': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/9.png',
#    'front_female': None,
#    'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/shiny/9.png',
# ...

# %%
r = requests.get('https://pokeapi.co/api/v2/pokemon/mewtwo')

# %%
r.status_code
# Out:
# 200

# %%
r.json()['sprites']
# Out:
# {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/150.png',
#  'back_female': None,
#  'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/shiny/150.png',
#  'back_shiny_female': None,
#  'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/150.png',
#  'front_female': None,
#  'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/150.png',
#  'front_shiny_female': None,
#  'other': {'dream_world': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/dream-world/150.svg',
#    'front_female': None},
#   'home': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/150.png',
#    'front_female': None,
#    'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/shiny/150.png',
# ...

# %%
r.json()['name']
# Out:
# 'mewtwo'

# %%
r.json()['abilities']
# Out:
# [{'ability': {'name': 'pressure',
#    'url': 'https://pokeapi.co/api/v2/ability/46/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'unnerve',
#    'url': 'https://pokeapi.co/api/v2/ability/127/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
r.json()['base_experience']
# Out:
# 340

# %%
r = requests.get('https://pokeapi.co/api/v2/pokemon/mankey')

# %%
r.status_code
# Out:
# 200

# %%
r.json()['name']
# Out:
# 'mankey'

# %%
r.json()['abilities']
# Out:
# [{'ability': {'name': 'vital-spirit',
#    'url': 'https://pokeapi.co/api/v2/ability/72/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'anger-point',
#    'url': 'https://pokeapi.co/api/v2/ability/83/'},
#   'is_hidden': False,
#   'slot': 2},
#  {'ability': {'name': 'defiant',
#    'url': 'https://pokeapi.co/api/v2/ability/128/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
r.json()['sprites']
# Out:
# {'back_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/56.png',
#  'back_female': None,
#  'back_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/back/shiny/56.png',
#  'back_shiny_female': None,
#  'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/56.png',
#  'front_female': None,
#  'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/56.png',
#  'front_shiny_female': None,
#  'other': {'dream_world': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/dream-world/56.svg',
#    'front_female': None},
#   'home': {'front_default': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/56.png',
#    'front_female': None,
#    'front_shiny': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/home/shiny/56.png',
# ...

# %%
r.json()['base_experience']
# Out:
# 61
